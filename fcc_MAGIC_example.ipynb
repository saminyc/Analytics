# %% [markdown]
# <a href="https://colab.research.google.com/github/saminyc/Analytics/blob/main/fcc_MAGIC_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Dataset
# Dua, D. and Graff, C. (2019). UCI Machine Learning Repository [http://archive.ics.uci.edu/ml]. Irvine, CA: University of California, School of Information and Computer Science.
#
# Donated by: P. Savicky Institute of Computer Science, AS of CR Czech Republic savicky '@' cs.cas.cz

# %%
cols = ["fLength", "fWidth", "fSize", "fConc", "fConc1", "fAsym", "fM3Long", "fM3Trans", "fAlpha", "fDist", "class"]
df = pd.read_csv("magic04.data", names=cols)
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %%
df["class"]=(df["class"]=="g").astype(int)

# %%
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist  class
# 0  40.0920   81.8828      1
# 1   6.3609  205.2610      1
# 2  76.9600  256.7880      1
# 3  10.4490  116.7370      1
# 4   4.6480  356.4620      1

# %%
for label in df.columns[ :-1]:
    plt.hist(df[df["class"]==1][label],color='blue', label='gamma', alpha=0.7, density=True)
    plt.hist(df[df["class"]==0][label],color='red', label='hadron', alpha=0.7, density=True)
    plt.title(label)
    plt.ylabel("Probability")
    plt.xlabel(label)
    plt.legend()
    plt.show()

# %% [markdown]
# # Train, validation, test datasets

# %%
train,valid,test = np.split(df.sample(frac=1), [ int(0.60*len(df)),int(0.80*len(df)) ])

# %% [markdown]
# Scaling Dataset

# %%
def scale_dataset(dataframe):
    X=dataframe[dataframe.cols[:-1]].values
    Y=dataframe[dataframe.cols[-1]].values

    #use the standard scaler lib used above
    scaler=StandardScaler()
    X=scaler.fit_transform(X)

    data = np.hstack((X,np.reshape(y, (-1,1))))

    return data,X,Y

# %%
train
# Out:
#         fLength   fWidth   fSize   fConc  fConc1    fAsym  fM3Long  fM3Trans  \
# 14652   26.0249   8.2571  2.5075  0.6816  0.4343  15.3165   7.8907   -8.9325
# 17295   39.8955  13.6530  2.5521  0.5498  0.2875 -34.6689 -27.0903   -9.3098
# 1799    70.0753  19.3644  3.1517  0.2327  0.1216  35.2450  59.7135   -8.1105
# 11039   50.1329  20.7712  2.9206  0.4262  0.2695  -9.4860  42.4254   10.3720
# 17734   17.3374  11.1958  2.2511  0.6548  0.4667   1.3232  26.5431  -13.4286
# ...         ...      ...     ...     ...     ...      ...      ...       ...
# 14280  106.6550  69.5269  4.0170  0.0920  0.0487 -49.3074 -46.8124   57.1702
# 792     32.2947  13.0008  2.4771  0.5600  0.3850  10.8002  26.7207  -12.7504
# 17635   18.5389  10.1402  2.2923  0.6276  0.3138   3.1107  -9.8429   -6.0326
# 6543    18.0147  14.7309  2.3901  0.5662  0.3809   3.9021 -15.1944    9.5231
# 11568   39.2972  16.7651  2.7882  0.2801  0.1507  24.6147 -23.7150   -8.0415
#
#         fAlpha     fDist  class
# ...
